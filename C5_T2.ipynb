# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
print('pre-process data here')
# Out:
# pre-process data here

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
credit["DEFAULT"]= credit["default payment next month"]

# %%
credit = credit.drop("default payment next month",axis=1)

# %%
#credit["ID"]= credit["ID"].astype('category')
#credit["AGE"]= credit["AGE"].astype('int')
#credit["SEX"]= credit["SEX"].astype('category')
#credit["EDUCATION"]= credit["EDUCATION"].astype('category')
#credit["MARRIAGE"]= credit["MARRIAGE"].astype('category')
#credit["PAY_0"]= credit["PAY_0"].astype('category')
#credit["PAY_2"]= credit["PAY_2"].astype('category')
#credit["PAY_3"]= credit["PAY_3"].astype('category')
#credit["PAY_4"]= credit["PAY_4"].astype('category')
#credit["PAY_5"]= credit["PAY_5"].astype('category')
#credit["PAY_6"]= credit["PAY_6"].astype('category')
#credit["DEFAULT"]= credit["DEFAULT"].astype('category')

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID           30000 non-null int64
# LIMIT_BAL    30000 non-null int64
# SEX          30000 non-null int64
# EDUCATION    30000 non-null int64
# MARRIAGE     30000 non-null int64
# AGE          30000 non-null int64
# PAY_0        30000 non-null int64
# PAY_2        30000 non-null int64
# PAY_3        30000 non-null int64
# PAY_4        30000 non-null int64
# PAY_5        30000 non-null int64
# PAY_6        30000 non-null int64
# BILL_AMT1    30000 non-null int64
# BILL_AMT2    30000 non-null int64
# BILL_AMT3    30000 non-null int64
# BILL_AMT4    30000 non-null int64
# BILL_AMT5    30000 non-null int64
# BILL_AMT6    30000 non-null int64
# PAY_AMT1     30000 non-null int64
# PAY_AMT2     30000 non-null int64
# PAY_AMT3     30000 non-null int64
# PAY_AMT4     30000 non-null int64
# PAY_AMT5     30000 non-null int64
# PAY_AMT6     30000 non-null int64
# ...

# %%
#df = pd.DataFrame(credit)

# %%
#creditshort = credit.head(50)

# %%
#df = pd.DataFrame(credit)

# %%
#df.info()

# %%
#df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT'],
#       dtype='object')

# %%
#age_bins = pd.cut(df.AGE, 7)
#df['age_bins'] = age_bins
#limit_bins = pd.cut(df.LIMIT_BAL, 10)
#df['limit_bins'] = limit_bins
#bill6_bins = pd.cut(df.BILL_AMT6, 14)
#df['bill6_bins'] = bill6_bins

#df2 = df[['ID', 'LIMIT_BAL', 'limit_bins', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'age_bins','PAY_0',
#       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'bill6_bins', 'PAY_AMT1',
#       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6','DEFAULT']]
#df2

# %%
#df2.to_csv('credit_prepro.csv')

# %%
#VISUALIZING THE DATA (don't convert to dataframe yet???)

# %%
#credit2 = pd.read_csv('credit_prepro.csv', header =1)

# %%
#df2.head()
# Out:
#   ID  LIMIT_BAL            limit_bins SEX EDUCATION MARRIAGE  AGE  \
# 0  1      20000    (9010.0, 109000.0]   2         2        1   24
# 1  2     120000  (109000.0, 208000.0]   2         2        2   26
# 2  3      90000    (9010.0, 109000.0]   2         2        2   34
# 3  4      50000    (9010.0, 109000.0]   2         2        1   37
# 4  5      50000    (9010.0, 109000.0]   1         2        1   57
#
#            age_bins PAY_0 PAY_2  ... BILL_AMT5 BILL_AMT6  \
# 0  (20.942, 29.286]     2     2  ...         0         0
# 1  (20.942, 29.286]    -1     2  ...      3455      3261
# 2  (29.286, 37.571]     0     0  ...     14948     15549
# 3  (29.286, 37.571]     0     0  ...     28959     29547
# 4  (54.143, 62.429]    -1     0  ...     19146     19131
#
#                 bill6_bins PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0  (-60760.071, 32187.571]        0       689         0         0         0
# ...

# %%
#df2.info

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'DEFAULT'],
#       dtype='object')

# %%
print('4 times as many people do not default vs. default')
plt.hist(credit['DEFAULT'], bins=2)
plt.title('Histogram of Default')
plt.xlabel('Default')
plt.ylabel('Frequency')
plt.show()
# Out:
# 4 times as many people do not default vs. default

# %%
from pylab import *

subplot(2,3,1)
plt.hist(credit['PAY_0'], bins=14)
plt.title('History Sept (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,2)
plt.hist(credit['PAY_2'], bins=14)
plt.title('History Aug (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,3)
plt.hist(credit['PAY_3'], bins=14)
plt.title('History July (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,4)
plt.hist(credit['PAY_4'], bins=14)
plt.title('History June (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,5)
plt.hist(credit['PAY_5'], bins=14)
plt.title('History May (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,6)
plt.hist(credit['PAY_6'], bins=14)
plt.title('History April (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# The majority of people do not submit delayed payments

# %%
from pylab import *

subplot(2,3,1)
plt.hist(credit['BILL_AMT1'], bins=14)
plt.title('Bill Sept (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,2)
plt.hist(credit['BILL_AMT2'], bins=14)
plt.title('Bill Aug (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,3)
plt.hist(credit['BILL_AMT3'], bins=14)
plt.title('Bill July (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,4)
plt.hist(credit['BILL_AMT4'], bins=14)
plt.title('Bill June (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,5)
plt.hist(credit['BILL_AMT5'], bins=14)
plt.title('Bill May (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,6)
plt.hist(credit['BILL_AMT6'], bins=14)
plt.title('Bill April (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
subplot(2,3,1)
plt.hist(credit['PAY_AMT1'], bins=14)
plt.title('Paid Sept (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,2)
plt.hist(credit['PAY_AMT2'], bins=14)
plt.title('Paid Aug (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,3)
plt.hist(credit['PAY_AMT3'], bins=14)
plt.title('Paid July (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,4)
plt.hist(credit['PAY_AMT4'], bins=14)
plt.title('Paid June (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,5)
plt.hist(credit['PAY_AMT5'], bins=14)
plt.title('Paid May (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,3,6)
plt.hist(credit['PAY_AMT6'], bins=14)
plt.title('Paid April (bin=14)')
plt.xlabel('Range')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
print('Most people are in their 30s \n there are more women than men \n most people went to college \n most people are single')

subplot(2,2,1)
plt.hist(credit['AGE'], bins=10)
plt.title('Age (bin=10)')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,2,2)
plt.hist(credit['SEX'])
plt.title('Sex')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,2,3)
plt.hist(credit['EDUCATION'])
plt.title('Education')
plt.xlabel('Range')
plt.ylabel('Frequency')

subplot(2,2,4)
plt.hist(credit['MARRIAGE'])
plt.title('Marriage')
plt.xlabel('Range')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Most people are in their 30s
#  there are more women than men
#  most people went to college
#  most people are single

# %%
subplot(2,3,1)
plt.plot(credit['PAY_0'])
plt.title('History Sept')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,2)
plt.plot(credit['PAY_2'])
plt.title('History Aug')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,3)
plt.plot(credit['PAY_3'])
plt.title('History July')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,4)
plt.plot(credit['PAY_4'])
plt.title('History June')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,5)
plt.plot(credit['PAY_5'])
plt.title('History May')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,6)
plt.plot(credit['PAY_6'])
plt.title('History April')
plt.xlabel('n')
plt.ylabel('Amount')

plt.tight_layout()
plt.show()

# %%
subplot(2,3,1)
plt.plot(credit['BILL_AMT1'])
plt.title('Bill Sept')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,2)
plt.plot(credit['BILL_AMT2'])
plt.title('Bill Aug')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,3)
plt.plot(credit['BILL_AMT3'])
plt.title('Bill July')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,4)
plt.plot(credit['BILL_AMT4'])
plt.title('Bill June')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,5)
plt.plot(credit['BILL_AMT5'])
plt.title('Bill May')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,6)
plt.plot(credit['BILL_AMT6'])
plt.title('Bill April')
plt.xlabel('n')
plt.ylabel('Amount')

plt.tight_layout()
plt.show()

# %%
subplot(2,3,1)
plt.plot(credit['PAY_AMT1'])
plt.title('Paid Sept')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,2)
plt.plot(credit['PAY_AMT2'])
plt.title('Paid Aug')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,3)
plt.plot(credit['PAY_AMT3'])
plt.title('Paid July')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,4)
plt.plot(credit['PAY_AMT4'])
plt.title('Paid June')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,5)
plt.plot(credit['PAY_AMT5'])
plt.title('Paid May')
plt.xlabel('n')
plt.ylabel('Amount')

subplot(2,3,6)
plt.plot(credit['PAY_AMT6'])
plt.title('Paid April')
plt.xlabel('n')
plt.ylabel('Amount')

plt.tight_layout()
plt.show()

# %%
plt.plot(credit['LIMIT_BAL'])
plt.title('Credit Limit')
plt.xlabel('Range')
plt.ylabel('Frequency')
plt.show()

# %%
plt.plot(credit['MARRIAGE'])
plt.title('Marriage')
plt.xlabel('Range')
plt.ylabel('Frequency')
plt.show()

# %%
print('SCATTER PLOTS')
# Out:
# SCATTER PLOTS

# %%
x = credit['PAY_0']
y = credit['PAY_2']
plt.scatter(x,y)
plt.show()

# %%
print('People with higher credit limit spend less of their limit')
plt.title('September Bill vs. Credit Limit')
x = credit['LIMIT_BAL']
y = credit['BILL_AMT1']
plt.scatter(x,y)
plt.xlabel('Credit Limit')
plt.ylabel('September Bill')
plt.show()
# Out:
# People with higher credit limit spend less of their limit

# %%
print('More people pay a small amount if their bill is high \n substantial proportion of people pays in full')
plt.title('August Bill vs. September Payment')
x = credit['BILL_AMT2']
y = credit['PAY_AMT1']
plt.scatter(x,y)
plt.xlabel('August Bill')
plt.ylabel('September Payment')
plt.show()
# Out:
# More people pay a small amount if their bill is high
#  substantial proportion of people pays in full

# %%
print('BOX PLOTS')
# Out:
# BOX PLOTS

# %%
A = credit['PAY_6']
plt.boxplot(A,0,'gD')
plt.show()

# %%
plt.title('Box Plots of Pay History')
box_plot_data=[credit['PAY_6'], credit['PAY_5'], credit['PAY_4'], credit['PAY_3'], credit['PAY_2'], credit['PAY_0']]
plt.boxplot(box_plot_data,patch_artist=True,labels=['April','May','June','July', 'August', 'September'])
plt.show()

# %%
plt.title('Box Plots of Paid Amounts')
box_plot_data=[credit['PAY_AMT6'], credit['PAY_AMT5'], credit['PAY_AMT4'], credit['PAY_AMT3'], credit['PAY_AMT2'], credit['PAY_AMT1']]
plt.boxplot(box_plot_data,patch_artist=True,labels=['April','May','June','July', 'August', 'September'])
plt.show()

# %%
plt.title('Box Plots of Bill Amounts')
box_plot_data=[credit['BILL_AMT6'], credit['BILL_AMT5'], credit['BILL_AMT4'], credit['BILL_AMT3'], credit['BILL_AMT2'], credit['BILL_AMT1']]
plt.boxplot(box_plot_data,patch_artist=True,labels=['April','May','June','July', 'August', 'September'])
plt.show()

# %%
print('CORRELATION MATRICES')
# Out:
# CORRELATION MATRICES

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                  ID  LIMIT_BAL       SEX  EDUCATION  MARRIAGE       AGE  \
# ID         1.000000   0.026179  0.018497   0.039177 -0.029079  0.018678
# LIMIT_BAL  0.026179   1.000000  0.024755  -0.219161 -0.108139  0.144713
# SEX        0.018497   0.024755  1.000000   0.014232 -0.031389 -0.090874
# EDUCATION  0.039177  -0.219161  0.014232   1.000000 -0.143464  0.175061
# MARRIAGE  -0.029079  -0.108139 -0.031389  -0.143464  1.000000 -0.414170
# AGE        0.018678   0.144713 -0.090874   0.175061 -0.414170  1.000000
# PAY_0     -0.030575  -0.271214 -0.057643   0.105364  0.019917 -0.039447
# PAY_2     -0.011215  -0.296382 -0.070771   0.121566  0.024199 -0.050148
# PAY_3     -0.018494  -0.286123 -0.066096   0.114025  0.032688 -0.053048
# PAY_4     -0.002735  -0.267460 -0.060173   0.108793  0.033122 -0.049722
# PAY_5     -0.022199  -0.249411 -0.055064   0.097520  0.035629 -0.053826
# PAY_6     -0.020270  -0.235195 -0.044008   0.082316  0.034345 -0.048773
# ...

# %%
print('Create massive correlation matrix plot \n Do not see much collinearity \n Pay History correlates quite well (September Pay histry is best) \n High credit limit correlates very poorly (low credit limit correlates very well) \n September paid amount also correlates poorly')
# Out:
# Create massive correlation matrix plot
#  Do not see much collinearity
#  Pay History correlates quite well (September Pay histry is best)
#  High credit limit correlates very poorly (low credit limit correlates very well)
#  September paid amount also correlates poorly

# %%
import seaborn as sns
data = credit
corr = data.corr()
ax = sns.heatmap(
    corr, vmin=-1, vmax=1, center=0, cmap=sns.diverging_palette(20, 220, n=200), square=True)
ax.set_xticklabels(
    ax.get_xticklabels(), rotation=45, horizontalalignment='right');
plt.title('Overall Correlation Matrix')
#sns.set(rc={'figure.figsize':(3,3)})
rcParams['figure.figsize'] = 15,15

# %%
print('COVARIANCE')
# Out:
# COVARIANCE

# %%
print('Entire Covariance Matrix (minus ID)')
data = credit.iloc[:,1:25]
covMat = data.cov()
print(covMat)
# Out:
# Entire Covariance Matrix (minus ID)
#               LIMIT_BAL          SEX     EDUCATION     MARRIAGE  \
# LIMIT_BAL  1.683446e+10  1571.050630 -22474.028945 -7323.669658
# SEX        1.571051e+03     0.239247      0.005502    -0.008014
# EDUCATION -2.247403e+04     0.005502      0.624651    -0.059184
# MARRIAGE  -7.323670e+03    -0.008014     -0.059184     0.272452
# AGE        1.730767e+05    -0.409726      1.275380    -1.992764
# PAY_0     -3.954593e+04    -0.031685      0.093584     0.011683
# PAY_2     -4.603765e+04    -0.041442      0.115025     0.015122
# PAY_3     -4.443225e+04    -0.038694      0.107861     0.020421
# PAY_4     -4.057181e+04    -0.034411      0.100528     0.020213
# PAY_5     -3.667056e+04    -0.030521      0.087340     0.021074
# PAY_6     -3.509308e+04    -0.024754      0.074816     0.020616
# BILL_AMT1  2.727020e+09 -1211.694332   1372.377644  -902.154685
# BILL_AMT2  2.570130e+09 -1085.595467   1054.657595  -802.517866
# ...

# %%
print('Only Covariance of default')
covMat['DEFAULT']
# Out:
# Only Covariance of default
# LIMIT_BAL   -8267.551759
# SEX            -0.008113
# EDUCATION       0.009187
# MARRIAGE       -0.005273
# AGE             0.053143
# PAY_0           0.151499
# PAY_2           0.130960
# PAY_3           0.116867
# PAY_4           0.105115
# PAY_5           0.096020
# PAY_6           0.089194
# BILL_AMT1    -600.394108
# BILL_AMT2    -419.289137
# BILL_AMT3    -405.153680
# BILL_AMT4    -271.199885
# BILL_AMT5    -170.597447
# BILL_AMT6    -132.796294
# PAY_AMT1     -501.374552
# PAY_AMT2     -560.210740
# PAY_AMT3     -411.076284
# PAY_AMT4     -369.515887
# PAY_AMT5     -349.562530
# PAY_AMT6     -392.426415
# DEFAULT         0.172276
# Name: DEFAULT, dtype: float64

# %%
print('Plot of Covariance of default')
covDefault = covMat['DEFAULT']
plt.plot(covDefault)
plt.title('Covariance of default')
plt.xlabel('Attribute')
plt.ylabel('Covariance')
# Out:
# Plot of Covariance of default
# Text(0, 0.5, 'Covariance')

# %%
print('Only Covariance of default (minus credit limit outlier) \n September Bill Amount correlates most negatively \n September Paid Amount is also very negative')
covDefault2 = covDefault.iloc[1:23]
plt.plot(covDefault2)
plt.title('Covariance of default (minus credit limit outlier)')
plt.xlabel('Attribute')
plt.ylabel('Covariance')
# Out:
# Only Covariance of default (minus credit limit outlier)
#  September Bill Amount correlates most negatively
#  September Paid Amount is also very negative
# Text(0, 0.5, 'Covariance')

# %%
print('Covariance of default (positive values only) \n September Payment History correlates most positively')
covDefault2 = covDefault.iloc[1:11]
plt.plot(covDefault2)
plt.title('Covariance of default (positive values only)')
plt.xlabel('Attribute')
plt.ylabel('Covariance')
# Out:
# Covariance of default (positive values only)
#  September Payment History correlates most positively
# Text(0, 0.5, 'Covariance')

# %%
print('INSIGHTFUL PLOTS')
# Out:
# INSIGHTFUL PLOTS

# %%
print('Payment history by sex')
g = sns.factorplot('PAY_0', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('Payment History')
# Out:
# Payment history by sex

# %%
print('A lower proportion of women defaulted vs. men')
defaulted = credit[credit['DEFAULT']==1]
g = sns.factorplot('SEX', data=credit, hue='DEFAULT', kind='count', aspect=1.75)
g.set_xlabels('Sex')
# Out:
# A lower proportion of women defaulted vs. men

# %%
df = pd.DataFrame(credit)

age_bins = pd.cut(df.AGE, 7)
df['age_bins'] = age_bins
limit_bins = pd.cut(df.LIMIT_BAL, 10)
df['limit_bins'] = limit_bins
bill1_bins = pd.cut(df.BILL_AMT1, 14)
df['bill1_bins'] = bill1_bins

df2 = df[['ID', 'LIMIT_BAL', 'limit_bins', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'age_bins','PAY_0',
       'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1','bill1_bins', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6','DEFAULT']]
df2.head()
# Out:
#    ID  LIMIT_BAL            limit_bins  SEX  EDUCATION  MARRIAGE  AGE  \
# 0   1      20000    (9010.0, 109000.0]    2          2         1   24
# 1   2     120000  (109000.0, 208000.0]    2          2         2   26
# 2   3      90000    (9010.0, 109000.0]    2          2         2   34
# 3   4      50000    (9010.0, 109000.0]    2          2         1   37
# 4   5      50000    (9010.0, 109000.0]    1          2         1   57
#
#            age_bins  PAY_0  PAY_2  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# 0  (20.942, 29.286]      2      2  ...          0          0          0
# 1  (20.942, 29.286]     -1      2  ...       3272       3455       3261
# 2  (29.286, 37.571]      0      0  ...      14331      14948      15549
# 3  (29.286, 37.571]      0      0  ...      28314      28959      29547
# 4  (54.143, 62.429]     -1      0  ...      20940      19146      19131
#
#    PAY_AMT1  PAY_AMT2 PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
print('Breakdown of defaults by age')
defaulted = df[df['DEFAULT']==1]
g = sns.factorplot('age_bins', data=df, hue='DEFAULT', kind='count', aspect=1.75)
g.set_xlabels('Age')
# Out:
# Breakdown of defaults by age

# %%
print('People with a lower credit limit tended to default more')
defaulted = df[df['DEFAULT']==1]
g = sns.factorplot('limit_bins', data=df, hue='DEFAULT', kind='count', aspect=1.75)
g.set_xlabels('Credit Limit')
# Out:
# People with a lower credit limit tended to default more

# %%
fig = sns.FacetGrid(df, hue='SEX', aspect=4)
fig.map(sns.kdeplot, 'BILL_AMT1', shade=True)
highest = df['BILL_AMT1'].max()
fig.set(xlim=(0,highest))
fig.set(title='Distribution of Bill Amount Grouped by Gender')
fig.add_legend()
